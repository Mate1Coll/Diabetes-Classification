# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Exploration

# %%
df = pd.read_csv("Assignment DataSet.csv")
df.head(10)
# Out:
#    Unnamed: 0  patient_nbr             race  gender      age  \
# 0           0     41186889        Caucasian  Female  [80-90)
# 1           1     83591073        Caucasian  Female  [80-90)
# 2           2     68337009            Other    Male  [60-70)
# 3           3     73175076        Caucasian    Male  [40-50)
# 4           4     31718349        Caucasian  Female  [70-80)
# 5           5     20909367         Hispanic  Female  [80-90)
# 6           6     86870088  AfricanAmerican  Female  [50-60)
# 7           7     52043301        Caucasian    Male  [60-70)
# 8           8     58716846  AfricanAmerican  Female  [60-70)
# 9           9    102729258        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         6                    7
# 1                  6                         1                   17
# 2                  1                         2                    1
# 3                  1                         1                    7
# 4                  1                         1                    7
# 5                  2                         6                    1
# 6                  1                         1                    7
# 7                  3                         1                    1
# 8                  1                        13                    7
# 9                  6                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  tolazamide  examide  \
# 0                13                  69  ...          No       No
# 1                 5                  34  ...          No       No
# 2                 1                  37  ...          No       No
# 3                 4                  56  ...          No       No
# 4                 1                  38  ...          No       No
# 5                 2                  61  ...          No       No
# 6                 3                  26  ...          No       No
# 7                 6                  66  ...          No       No
# 8                 9                  74  ...          No       No
# 9                12                  68  ...          No       No
#
#    citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# 0       Steady   Steady                   No                   No
# 1       Steady       No                   No                   No
# 2       Steady   Steady                   No                   No
# 3       Steady       Up                   No                   No
# 4       Steady       No                   No                   No
# 5           No     Down                   No                   No
# 6           No     Down                   No                   No
# 7           No       No                   No                   No
# 8           No   Steady                   No                   No
# 9       Steady       Up                   No                   No
#
#    metformin-rosiglitazone  change  diabetesMed  readmitted
# 0                       No      No          Yes          NO
# 1                       No      No           No          NO
# 2                       No      No          Yes          NO
# 3                       No      Ch          Yes         YES
# 4                       No      No           No          NO
# 5                       No      Ch          Yes          NO
# 6                       No      Ch          Yes         YES
# 7                       No      No           No          NO
# 8                       No      No          Yes          NO
# 9                       No      Ch          Yes          NO
#
# [10 rows x 38 columns]

# %%
print('Number of columns:', len(df.columns)) # -1 to exclude the target column
print('Number of samples:', len(df))
# Out:
# Number of columns: 38
# Number of samples: 5000

# %%
features = df.columns[2:-1]
df_features = df[features]
patient_class = df.columns[-1]
df_class = df[patient_class]

# %%
print('Features: ', features)
print('Number of features:', len(features))
# Out:
# Features:  Index(['race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'diag_4', 'number_diagnoses', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'troglitazone', 'tolazamide',
#        'examide', 'citoglipton', 'insulin', 'glyburide-metformin',
#        'glipizide-metformin', 'metformin-rosiglitazone', 'change',
#        'diabetesMed'],
#       dtype='object')
# Number of features: 35

# %%
# Statistical summary of the dataset of both numerical and categorical columns
df_features.describe(include='all')
# Out:
#              race  gender      age  admission_type_id  \
# count        5000    5000     5000         5000.00000
# unique          6       2       10                NaN
# top     Caucasian  Female  [70-80)                NaN
# freq         3759    2701     1241                NaN
# mean          NaN     NaN      NaN            2.03220
# std           NaN     NaN      NaN            1.45643
# min           NaN     NaN      NaN            1.00000
# 25%           NaN     NaN      NaN            1.00000
# 50%           NaN     NaN      NaN            1.00000
# 75%           NaN     NaN      NaN            3.00000
# max           NaN     NaN      NaN            8.00000
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# count                5000.000000          5000.000000       5000.000000
# unique                       NaN                  NaN               NaN
# top                          NaN                  NaN               NaN
# freq                         NaN                  NaN               NaN
# mean                    3.700400             5.704000          4.430400
# std                     5.265148             3.951393          3.009612
# min                     1.000000             1.000000          1.000000
# 25%                     1.000000             1.000000          2.000000
# 50%                     1.000000             7.000000          4.000000
# 75%                     3.250000             7.000000          6.000000
# max                    28.000000            20.000000         14.000000
#
#         num_lab_procedures  num_procedures  num_medications  ...  \
# count          5000.000000     5000.000000      5000.000000  ...
# unique                 NaN             NaN              NaN  ...
# top                    NaN             NaN              NaN  ...
# freq                   NaN             NaN              NaN  ...
# mean             43.195200        1.360400        15.904600  ...
# std              19.761316        1.711227         8.117406  ...
# min               1.000000        0.000000         1.000000  ...
# 25%              31.000000        0.000000        10.000000  ...
# 50%              44.000000        1.000000        15.000000  ...
# 75%              57.000000        2.000000        20.000000  ...
# max             108.000000        6.000000        65.000000  ...
#
#         troglitazone  tolazamide  examide  citoglipton  insulin  \
# count           5000        5000     5000         5000     5000
# unique             1           2        1            2        4
# top               No          No       No       Steady       No
# freq            5000        4999     5000         3457     2329
# mean             NaN         NaN      NaN          NaN      NaN
# std              NaN         NaN      NaN          NaN      NaN
# min              NaN         NaN      NaN          NaN      NaN
# 25%              NaN         NaN      NaN          NaN      NaN
# 50%              NaN         NaN      NaN          NaN      NaN
# 75%              NaN         NaN      NaN          NaN      NaN
# max              NaN         NaN      NaN          NaN      NaN
#
#         glyburide-metformin  glipizide-metformin  metformin-rosiglitazone  \
# count                  5000                 5000                     5000
# unique                    4                    2                        1
# top                      No                   No                       No
# freq                   4967                 4999                     5000
# mean                    NaN                  NaN                      NaN
# std                     NaN                  NaN                      NaN
# min                     NaN                  NaN                      NaN
# 25%                     NaN                  NaN                      NaN
# 50%                     NaN                  NaN                      NaN
# 75%                     NaN                  NaN                      NaN
# max                     NaN                  NaN                      NaN
#
#        change diabetesMed
# count    5000        5000
# unique      2           2
# top        No         Yes
# freq     2692        3860
# mean      NaN         NaN
# std       NaN         NaN
# min       NaN         NaN
# 25%       NaN         NaN
# 50%       NaN         NaN
# 75%       NaN         NaN
# max       NaN         NaN
#
# [11 rows x 35 columns]

# %% [markdown]
# ## Data quality

# %% [markdown]
# ### Missing values

# %% [markdown]
# Now, we are interested in studying the data quality of each feature. First we look into the features with missing values:

# %%
nan_values = df.isna().sum()
print('Number of missing values in each column:')
# Out:
# Number of missing values in each column:

# %% [markdown]
# There is no Nan values. However, by observing the data, we can note how the missing values are represented as '?':

# %%
# Count the number of missing values in each column
missing_values = df[df == '?'].count()
missing_values = missing_values[missing_values > 0]/len(df)*100
missing_values = missing_values.sort_values(ascending=False)
missing_values
# Out:
# tolbutamide    79.86
# race            2.24
# dtype: float64

# %% [markdown]
# The features 'race' and 'tolbutamide' are the only ones with missing values. For the 'tolbutamide' feature, since there is an almost $80\%$ of missing values, we will not consider this feature.

# %%
df = df.drop('tolbutamide', axis=1)
df
# Out:
#       Unnamed: 0  patient_nbr       race  gender      age  admission_type_id  \
# 0              0     41186889  Caucasian  Female  [80-90)                  1
# 1              1     83591073  Caucasian  Female  [80-90)                  6
# 2              2     68337009      Other    Male  [60-70)                  1
# 3              3     73175076  Caucasian    Male  [40-50)                  1
# 4              4     31718349  Caucasian  Female  [70-80)                  1
# ...          ...          ...        ...     ...      ...                ...
# 4995        4995      6316443  Caucasian  Female  [80-90)                  1
# 4996        4996     96364728  Caucasian    Male  [70-80)                  2
# 4997        4997    101621745  Caucasian    Male  [50-60)                  1
# 4998        4998     21969333  Caucasian    Male  [70-80)                  1
# 4999        4999     41306418  Caucasian  Female  [70-80)                  1
#
#       discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                            6                    7                13
# 1                            1                   17                 5
# 2                            2                    1                 1
# 3                            1                    7                 4
# 4                            1                    7                 1
# ...                        ...                  ...               ...
# 4995                         1                    7                 3
# 4996                         1                    1                 8
# 4997                         1                    2                 1
# 4998                         1                    7                 2
# 4999                         1                    7                 9
#
#       num_lab_procedures  ...  tolazamide  examide  citoglipton  insulin  \
# 0                     69  ...          No       No       Steady   Steady
# 1                     34  ...          No       No       Steady       No
# 2                     37  ...          No       No       Steady   Steady
# 3                     56  ...          No       No       Steady       Up
# 4                     38  ...          No       No       Steady       No
# ...                  ...  ...         ...      ...          ...      ...
# 4995                  47  ...          No       No       Steady       No
# 4996                  52  ...          No       No       Steady       No
# 4997                  17  ...          No       No       Steady   Steady
# 4998                  42  ...          No       No           No       No
# 4999                  57  ...          No       No       Steady       No
#
#       glyburide-metformin  glipizide-metformin  metformin-rosiglitazone  \
# 0                      No                   No                       No
# 1                      No                   No                       No
# 2                      No                   No                       No
# 3                      No                   No                       No
# 4                      No                   No                       No
# ...                   ...                  ...                      ...
# 4995                   No                   No                       No
# 4996                   No                   No                       No
# 4997                   No                   No                       No
# 4998                   No                   No                       No
# 4999                   No                   No                       No
#
#       change  diabetesMed  readmitted
# 0         No          Yes          NO
# 1         No           No          NO
# 2         No          Yes          NO
# 3         Ch          Yes         YES
# 4         No           No          NO
# ...      ...          ...         ...
# 4995      Ch          Yes         YES
# 4996      Ch          Yes         YES
# 4997      Ch          Yes          NO
# 4998      No          Yes         YES
# 4999      No           No         YES
#
# [5000 rows x 37 columns]

# %% [markdown]
# For the 'race' feature, we can treat this problem in different ways. First, we can consider deleting those instances, but it can be reflected in a decreasing of data quantity. Another option is assigning the most frequent race to the instances with no race in the data or even providing a random value from the possible races previously represented. These possibilities may decrease the data quality.

# %%
# Count the occurrences of each value in the 'race' column
n_rv = df['race'].value_counts()

# Print the number of values in each category
print('Number of values:', n_rv)
# Out:
# Number of values: race
# Caucasian          3759
# AfricanAmerican     923
# ?                   112
# Hispanic             95
# Other                72
# Asian                39
# Name: count, dtype: int64

# %%
# Replace missing values ('?') in the 'race' column with the most frequent race
df.loc[df['race'] == '?', 'race'] = n_rv.index[0]

# %% [markdown]
# ### Uninformative features

# %% [markdown]
# Then, we look for features which do not give any information.

# %%
dict_vc = {}
for column in df.columns:
    dict_vc[column] = df[column].nunique()
dict_vc
# Out:
# {'Unnamed: 0': 5000,
#  'patient_nbr': 4837,
#  'race': 5,
#  'gender': 2,
#  'age': 10,
#  'admission_type_id': 7,
#  'discharge_disposition_id': 20,
#  'admission_source_id': 11,
#  'time_in_hospital': 14,
#  'num_lab_procedures': 99,
#  'num_procedures': 7,
#  'num_medications': 62,
#  'number_outpatient': 22,
#  'number_emergency': 13,
#  'number_inpatient': 15,
#  'diag_1': 371,
#  'diag_2': 357,
#  'diag_3': 377,
#  'diag_4': 5000,
#  'number_diagnoses': 12,
#  'chlorpropamide': 3,
#  'glimepiride': 4,
#  'acetohexamide': 1,
#  'glyburide': 4,
#  'pioglitazone': 4,
#  'rosiglitazone': 4,
#  'troglitazone': 1,
#  'tolazamide': 2,
#  'examide': 1,
#  'citoglipton': 2,
#  'insulin': 4,
#  'glyburide-metformin': 4,
#  'glipizide-metformin': 2,
#  'metformin-rosiglitazone': 1,
#  'change': 2,
#  'diabetesMed': 2,
#  'readmitted': 2}

# %%
uninformative_columns = [column for column in df.columns if df[column].nunique() == 1]
uninformative_columns
# Out:
# ['acetohexamide', 'troglitazone', 'examide', 'metformin-rosiglitazone']

# %% [markdown]
# This features does not provide additional information. Therefore, we discard them.

# %%
df = df.drop(uninformative_columns, axis=1)

# %% [markdown]
# ### Outliers

# %% [markdown]
# Not for now

# %% [markdown]
# ## Data manipulation

# %% [markdown]
# ### Categorical values

# %% [markdown]
# In this section we convert the categorical values to integer identifiers.

# %%
# Identify categorical columns
categorical_columns = df.select_dtypes(include='object').columns
categorical_columns
# Out:
# Index(['race', 'gender', 'age', 'chlorpropamide', 'glimepiride', 'glyburide',
#        'pioglitazone', 'rosiglitazone', 'tolazamide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin', 'change', 'diabetesMed',
#        'readmitted'],
#       dtype='object')

# %%
# Convert the categorical columns to the 'category' data type
df[categorical_columns] = df[categorical_columns].astype('category')

# Create a mapping of the original categorical values to the new integer identifiers
category_mapping = {
    col: {code: cat for code, cat in enumerate(df[col].astype('category').cat.categories)}
    for col in categorical_columns
}

reverse_category_mapping = {
    col: {cat: code for code, cat in enumerate(df[col].astype('category').cat.categories)}
    for col in categorical_columns
}

# Assign integer identifiers to the categorical columns
df[categorical_columns] = df[categorical_columns].apply(lambda x: x.cat.codes)

category_mapping
# Out:
# {'race': {0: 'AfricanAmerican',
#   1: 'Asian',
#   2: 'Caucasian',
#   3: 'Hispanic',
#   4: 'Other'},
#  'gender': {0: 'Female', 1: 'Male'},
#  'age': {0: '[0-10)',
#   1: '[10-20)',
#   2: '[20-30)',
#   3: '[30-40)',
#   4: '[40-50)',
#   5: '[50-60)',
#   6: '[60-70)',
#   7: '[70-80)',
#   8: '[80-90)',
#   9: '[90-100)'},
#  'chlorpropamide': {0: 'No', 1: 'Steady', 2: 'Up'},
#  'glimepiride': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'glyburide': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'pioglitazone': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'rosiglitazone': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'tolazamide': {0: 'No', 1: 'Steady'},
#  'citoglipton': {0: 'No', 1: 'Steady'},
#  'insulin': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'glyburide-metformin': {0: 'Down', 1: 'No', 2: 'Steady', 3: 'Up'},
#  'glipizide-metformin': {0: 'No', 1: 'Steady'},
#  'change': {0: 'Ch', 1: 'No'},
#  'diabetesMed': {0: 'No', 1: 'Yes'},
#  'readmitted': {0: 'NO', 1: 'YES'}}

# %% [markdown]
# # Model Checking

# %%
dClass = df[df.columns[-1]]
dFeatures = df[df.columns[2:-1]]

print('Number of Features columns:', len(dFeatures.columns)) # -1 to exclude the target column
print('Number of samples:', len(dFeatures))
# Out:
# Number of Features columns: 30
# Number of samples: 5000

# %%
# Convert the DataFrame to a NumPy array
dFeatures = dFeatures.to_numpy()
dClass = dClass.to_numpy()

# %%
# Classification
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=10, shuffle=True) # Define the split - 10 splits

score = []

# Handling of division of data is automaticly done by this function

for train, test in kf.split(dFeatures, dClass): # Split the data n_splits times

    dClass_training = dClass[train]
    dClass_test = dClass[test]
    dFeat_training = dFeatures[train, :]
    dFeat_test = dFeatures[test, :]
    model = KNeighborsClassifier(n_neighbors=3) # Creates an empty model and define the parameters
    model.fit(dFeat_training, dClass_training) # Train the model (dFeat = X, dClass = Y), actually is not trainning it is just storing the data
    tRes = model.score(dFeat_test, dClass_test) # Temporary result
    score.append(tRes)

print('Average accuracy: ', np.mean(score)) # Test the model
print('Standard deviation: ', np.std(score)) # Test the model
print('Number of splits: ', len(score)) # Test the model
# Out:
# Average accuracy:  0.5204
# Standard deviation:  0.026043041297052847
# Number of splits:  10

# %% [markdown]
# # Comments

# %% [markdown]
# * Reescale values?
# * Outliers?
# * Missing values? 'Race' treatment?
# * Apply different methods and metrics to get the best one.
